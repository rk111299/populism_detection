# %% [markdown]
# Preparing tweets for Annotation

# %%
# Mount drive to colab to import data over
from google.colab import drive
drive.mount("/content/drive")

# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import re

pd.set_option('max_colwidth', 400)
# Out:
# Mounted at /content/drive

# %%
# Import data into pandas dataframes
poli_tweets_2017 = pd.read_csv('/content/drive/MyDrive/Diss_data/Politicians_Tweets_2017.csv')

poli_tweets_2019 = pd.read_csv('/content/drive/MyDrive/Diss_data/Politicians_Tweets_2019.csv')

# %%
poli_tweets_2017
# Out:
#            conversation_id        username                 create_at  \
# 0       877624914987163651        SKinnock  2017-06-21T20:30:59.000Z
# 1       877540748652150785        SKinnock  2017-06-21T14:56:33.000Z
# 2       877209374296616960        SKinnock  2017-06-20T16:59:47.000Z
# 3       877151434495733760        SKinnock  2017-06-20T13:09:33.000Z
# 4       877146946703687680        SKinnock  2017-06-20T12:51:43.000Z
# ...                    ...             ...                       ...
# 229893  861217616232411137  jamesblanchard  2017-05-07T13:54:15.000Z
# 229894  859512676204109828  jamesblanchard  2017-05-02T20:59:25.000Z
# 229895  859512062657081347  jamesblanchard  2017-05-02T20:56:59.000Z
# 229896  854466902927843328  jamesblanchard  2017-04-18T22:49:19.000Z
# 229897  850723819664887811  jamesblanchard  2017-04-08T14:55:38.000Z
#
# ...

# %%
poli_tweets_2019
# Out:
#             conversation_id     username                 create_at  \
# 0       1209156155349622787     SKinnock  2019-12-23T16:57:47.000Z
# 1       1208081373224996869     SKinnock  2019-12-20T17:46:59.000Z
# 2       1207687004630028288     SKinnock  2019-12-19T15:39:54.000Z
# 3       1207645319804133376     SKinnock  2019-12-19T12:54:15.000Z
# 4       1207641465175891969     SKinnock  2019-12-19T12:38:56.000Z
# ...                     ...          ...                       ...
# 260131  1185090605128605696  AnnaPerrett  2019-10-18T07:09:52.000Z
# 260132  1184395982697648128  AnnaPerrett  2019-10-16T09:09:41.000Z
# 260133  1184161559439912960  AnnaPerrett  2019-10-15T17:38:11.000Z
# 260134  1184006207750713344  AnnaPerrett  2019-10-15T07:20:52.000Z
# 260135  1183852804655538177  AnnaPerrett  2019-10-14T21:11:18.000Z
#
# ...

# %% [markdown]
# # Splitting up tweets for annotation give 200 each, but say as many as they can do is fine.
# # STEPS
# 1. Split dataframe into 200 tweet chunks
# 2. name each df, check for missing values, remove politician account names
# 3. write each df into a separate csv, turn into a google sheet / excel file
# 4. double check each one
# 5. send out, give a deadline
# 6. get back and double check every row filled out!

# %%
# 2017 GENERAL ELECTION Elli, Izzy, Emily, Nancy LV, Josh, Alex

# %%
# Getting fraction of the data
np.random.seed(1234)
poli17_frac = poli_tweets_2017.sample(frac=0.01) # get fraction of tweets to give out to people 
poli17_frac[['populist', 'reason']] = np.nan
poli17_frac = poli17_frac[['text', 'populist', 'reason']]
poli17_frac
# Out:
#                                                                                                                                                    text  \
# 28860                Amazing turnout #wembley #arena @ssearena the best #tamil dance and singing acts plus an amazing live band https://t.co/MF0QqimiE1
# 174527                                 Lib Dems to WIN General Election? Shock Daily Star poll reveals NEW challenger for power https://t.co/JxaT5sZNbE
# 47582                 A new @LibDems #GE2027 manifesto discussed campaigning in Chelsea this afternoon: https://t.co/86Cpio9AY7 https://t.co/sEqwSSX1vh
# 114673          Something needs to be done about fly tipping in William Knibb ward! The council now have some fancy software... https://t.co/eQKPXdTaIQ
# 224741  Yes and yes. So proud of the Labour manifesto and a fantastic, fair honest campaign we have run locally and nationally. https://t.co/uDYAjheFmo
# ...

# %%
# Elli_tweets
Elli_tweets = poli17_frac[0:200]
Elli_tweets.to_csv('ElliWaters_Tweets.csv')
# !cp ElliWaters_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Izzy_tweets
Izzy_tweets = poli17_frac[201:400]
Izzy_tweets.to_csv('IzzyTiffin_Tweets.csv')
# !cp IzzyTiffin_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Emily_tweets
Emily_tweets = poli17_frac[401:600]
Emily_tweets.to_csv('EmilyAshley_Tweets.csv')
# !cp EmilyAshley_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Nancy LV tweets
NancyLV_tweets = poli17_frac[601:800]
NancyLV_tweets.to_csv('NancyLV_Tweets.csv')
# !cp NancyLV_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Josh tweets
Josh_tweets = poli17_frac[801:1000]
Josh_tweets.to_csv('JoshMann_Tweets.csv')
# !cp JoshMann_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Alex tweets
Alex_tweets = poli17_frac[1001:1200]
Alex_tweets.to_csv('AlexOtway_Tweets.csv')
# !cp AlexOtway_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Agreement test tweets
agreement_tweets = poli17_frac[1200:1235]
agreement_tweets.to_csv('agreement_tweets.csv')
# !cp agreement_tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Rob tweets to annotate
rob_tweets = poli17_frac[1400:1650]
rob_tweets.to_csv('rob_tweets.csv')
# !cp rob_tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Rob batch2 tweets to annotate
rob2_tweets = poli17_frac[1651:2200]
rob2_tweets.to_csv('rob2_tweets.csv')
# !cp rob2_tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Writing df to csv
poli17_frac.to_csv('test.csv')
# !cp test.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# 2019 GENERAL ELECTION Ben, Laura, Zella, Jed, Nancy B

# %%
# Getting fraction of the data
np.random.seed(1234)
poli19_frac = poli_tweets_2019.sample(frac=0.01) # get fraction of tweets to give out to people 
poli19_frac[['populist', 'reason']] = np.nan
poli19_frac = poli19_frac[['text', 'populist', 'reason']]
poli19_frac
# Out:
#                                                                                                                                                                                                                                                                                                                          text  \
# 109                                                                                                                                                                                                                   Focus on The Community\nFocus on the Region\nFocus on Wales...\n#plaidcymru2019 https://t.co/tgae3rCdDH
# 39893       A massive uplift is building houses! (Or stopping the head-long building of additional workplaces). Once we have a balanced town, we will have affordable homes FOR EVERYONE.  \nou just want the political power of being the one who decides who can have a subsidy from the taxpayers. https://t.co/7XwRmDuMEo
# ...

# %%
# Ben tweets
Ben_tweets = poli19_frac[0:200]
Ben_tweets.to_csv('BenWilliams_Tweets.csv')
# !cp BenWilliams_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Laura tweets
Laura_tweets = poli19_frac[201:400]
Laura_tweets.to_csv('LauraCrossley_Tweets.csv')
# !cp LauraCrossley_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Zella tweets
Zella_tweets = poli19_frac[401:600]
Zella_tweets.to_csv('ZellaRidley_Tweets.csv')
# !cp ZellaRidley_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Jed tweets
Jed_tweets = poli19_frac[601:800]
Jed_tweets.to_csv('JedSimister_Tweets.csv')
# !cp JedSimister_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Nancy_B tweets
NancyB_tweets = poli19_frac[801:1000]
NancyB_tweets.to_csv('NancyBrewin_Tweets.csv')
# !cp NancyBrewin_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Chloe tweets
Chloe_tweets = poli19_frac[1001:1200]
Chloe_tweets.to_csv('ChloeGifford_Tweets.csv')
# !cp ChloeGifford_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# rob batch 3 tweets
rob3_tweets = poli19_frac[1201:1750]
rob3_tweets.to_csv('rob3_Tweets.csv')
# !cp rob3_Tweets.csv "drive/My Drive/Diss_data/dataframes4annotation"

# %%
# Agreement test tweets
agreement_tweets = poli19_frac[1320:1370]
agreement_tweets.to_csv('agreement_tweets.csv')
# !cp agreement_tweets2.csv "drive/My Drive/Diss_data/annotation_agreement"
agreement_tweets
# Out:
#                                                                                                                                                                                                                                                                                                                                   text  \
# 15765                                                                                    Domestic violence is still not prioritised despite 173 deaths last year. Police resources are a huge concern - John Sutherland, (Met Police Chief Supt) says that between 2010-2018 we have lost 44,000 police officers and staff. #Newsnight
# 197903                                                                                                                                                                                                                       Well said that lady ! She knows more about the political situation than most MP”s https://t.co/rRj83Dyw97
# ...
